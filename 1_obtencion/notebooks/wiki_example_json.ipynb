# %% [markdown]
# # Lectura de un archivo JSON
#
# Vamos a abrir el archivo wiki_example.json, que contiene el ejemplo de la wikipedia

# %%
# === Datos ===
DATA_URL = "https://raw.githubusercontent.com/aaleta/cex_2026/main/1_obtencion/data/"

import os, urllib.request
def datos(nombre):
    if not os.path.exists(nombre) and DATA_URL:
        urllib.request.urlretrieve(DATA_URL + nombre, nombre)
    if not os.path.exists(nombre):
        raise FileNotFoundError(f"Falta '{nombre}': súbelo a Colab o define DATA_URL")
    return nombre

for _f in ['wiki_example.json']:
    datos(_f)
print('Datos listos:', 'wiki_example.json')
# Out:
# Datos listos: wiki_example.json

# %%
import json

with open("wiki_example.json") as f:
  dict_data = json.load(f)

dict_data
# Out:
# {'first_name': 'John',
#  'last_name': 'Smith',
#  'is_alive': True,
#  'age': 27,
#  'address': {'street_address': '21 2nd Street',
#   'city': 'New York',
#   'state': 'NY',
#   'postal_code': '10021-3100'},
#  'phone_numbers': [{'type': 'home', 'number': '212 555-1234'},
#   {'type': 'office', 'number': '646 555-4567'}],
#  'children': ['Catherine', 'Thomas', 'Trevor'],
#  'spouse': None}

# %% [markdown]
# ## Accediendo a la información
#
# Tenemos un JSON (o diccionario para Python) con cierta información sobre una persona.
#
# Por supuesto este es un caso muy tonto, y podemos ver toda la información de un vistazo, pero aún así vamos a ver como accederíamos programáticamente a esta información.

# %% [markdown]
# ### ¿Cómo se llama esta persona?

# %%
## TODO: Busca el nombre bajo la "key" first_name?

# %% [markdown]
# ### ¿Cuál es número de su oficina?

# %%
## TODO: De entre los números de telefono registrados, quédate con el que tenga type 'office'

# %% [markdown]
# ### ¿Cuantos hijos tiene?

# %%
## TODO: La key "children" nos da una lista con los nombres de sus hijos, solo tenemos que contarlas...

# %% [markdown]
# ## Una pequeña explicación
#
# Hemos ido recuperando información accediendo a la misma mediante diferentes claves "first_name", "children", etc.
#
# Para ello tenemos que saber qué claves hay, y qué tipo de datos aguardan. Estas especificaciones se conocen como "Schema"
