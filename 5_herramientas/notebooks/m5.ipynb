# %% [markdown]
# # M5 · Modelos sencillos y explicables
#
# Los primeros modelos que aprenden de todas las variables — y que podemos **leer**.

# %%
# === Datos ===
DATA_URL = "https://raw.githubusercontent.com/aaleta/cex_2026/main/5_herramientas/data/"

import os, urllib.request
def datos(nombre):
    if not os.path.exists(nombre) and DATA_URL:
        urllib.request.urlretrieve(DATA_URL + nombre, nombre)
    if not os.path.exists(nombre):
        raise FileNotFoundError(f"Falta '{nombre}': súbelo a Colab o define DATA_URL")
    return nombre

for _f in ['bizi_model.parquet']:
    datos(_f)
print('Datos listos:', ['bizi_model.parquet'])

# %% [markdown]
# ## Cargar y preparar

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
m = pd.read_parquet("bizi_model.parquet")
feats = ["num_vehicles_available","num_docks_available","occupancy_ratio","capacity",
         "is_renting","bikes_lag15","bikes_lag30","delta_30","hour","dow","is_weekend","month","is_holiday"]
tr, te = m[m.split=="train"], m[m.split=="test"]
Xtr, ytr, Xte, yte = tr[feats], tr.empty_in_30min, te[feats], te.empty_in_30min
def sc(p): return dict(acc=round(accuracy_score(yte,p),3), prec=round(precision_score(yte,p,zero_division=0),3),
                       rec=round(recall_score(yte,p,zero_division=0),3), f1=round(f1_score(yte,p,zero_division=0),3))

# %% [markdown]
# ## 1 · Regresión logística (y una sorpresa)
# Entrena una regresión logística con las variables `feats` (imputa y estandariza dentro de un `pipeline`). Mira su F1 con el umbral por defecto y compáralo con la persistencia de M4.

# %%
# TODO: completa este código (mira el enunciado de arriba)

# %% [markdown]
# ## 2 · Arreglar el desbalanceo
# Vuelve a entrenarla diciéndole que las clases pesan distinto (`class_weight='balanced'`). ¿Qué le pasa ahora al recall y a la precisión?

# %%
# TODO: completa este código (mira el enunciado de arriba)

# %% [markdown]
# ## 3 · ¿Qué ha aprendido? Los coeficientes
# Extrae los coeficientes del modelo, ordénalos y dibújalos en barras. El signo indica si la variable empuja hacia 'vacía' o en contra.

# %%
# TODO: completa este código (mira el enunciado de arriba)

# %% [markdown]
# > ¿Tiene sentido el signo de cada variable?

# %% [markdown]
# ## 4 · Un árbol que se lee
# Entrena un árbol de decisión poco profundo (`max_depth=3`) y dibújalo con `plot_tree`. Fíjate en la primera pregunta que hace en la raíz.

# %%
# TODO: completa este código (mira el enunciado de arriba)

# %% [markdown]
# > ¿Cuál es la **primera** pregunta que hace el árbol en la raíz? ¿Sobre qué variable?
