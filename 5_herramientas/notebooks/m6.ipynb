# %% [markdown]
# # M6 · Modelos 'caja negra'
#
# Toda la potencia: *gradient boosting*. Ganamos precisión y perdemos transparencia — y veremos cómo recuperar algo de ella.

# %%
# === Datos ===
DATA_URL = "https://raw.githubusercontent.com/aaleta/cex_2026/main/5_herramientas/data/"

import os, urllib.request
def datos(nombre):
    if not os.path.exists(nombre) and DATA_URL:
        urllib.request.urlretrieve(DATA_URL + nombre, nombre)
    if not os.path.exists(nombre):
        raise FileNotFoundError(f"Falta '{nombre}': súbelo a Colab o define DATA_URL")
    return nombre

for _f in ['bizi_model.parquet']:
    datos(_f)
print('Datos listos:', ['bizi_model.parquet'])

# %% [markdown]
# ## Cargar (ahora incluimos la estación como variable)

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.inspection import permutation_importance
from sklearn.metrics import average_precision_score, precision_recall_curve
m = pd.read_parquet("bizi_model.parquet")
feats = ["num_vehicles_available","num_docks_available","occupancy_ratio","capacity",
         "is_renting","bikes_lag15","bikes_lag30","delta_30","hour","dow","is_weekend",
         "month","is_holiday","station_id"]
tr, te = m[m.split=="train"], m[m.split=="test"]

# %% [markdown]
# ## 1 · Entrenar el gradient boosting
# No hace falta ni estandarizar ni imputar: los árboles se lo comen todo (NaN incluidos). Entrena un `HistGradientBoostingClassifier` con las variables `feats` (ahora incluye `station_id`) y mide su AP y su mejor F1 posible.

# %%
# TODO: completa este código (mira el enunciado de arriba)

# %% [markdown]
# ## 2 · Abrir la caja negra: importancia por permutación
# Si barajo (rompo) una variable, ¿cuánto empeora el modelo? Usa `permutation_importance` sobre una muestra del test y ordena las variables por cuánto cae el AP al barajarlas.

# %%
# TODO: completa este código (mira el enunciado de arriba)

# %% [markdown]
# > ¿Coincide con lo que viste en los coeficientes de M5? ¿Qué variable nueva asoma arriba?

# %% [markdown]
# **Puente a M7:** la importancia dice *qué* variables importan, no si el modelo es **bueno**. Para eso, con datos desbalanceados, hay que evaluar bien.
